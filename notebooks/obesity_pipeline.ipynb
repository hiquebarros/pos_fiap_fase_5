# %% [markdown]
# # Pipeline ML — Predição de Obesidade
#
# EDA e documentação. Treinamento reproduzível: `train/train.py`.

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns

ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT / 'train'))

from preprocessing import load_data

df = load_data()
df.head()

# %%
df.info()
df['Obesity'].value_counts()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
df['Obesity'].value_counts().plot(kind='bar', ax=ax[0], title='Distribuição da target')
sns.boxplot(data=df, x='Obesity', y='BMI', ax=ax[1])
ax[1].tick_params(axis='x', rotation=45)
plt.tight_layout()

# %% [markdown]
# ## Treinamento
#
# ```bash
# cd train && python train.py
# ```

# %%
import json
metrics = json.loads((ROOT / 'models' / 'metrics.json').read_text())
print(f"Modelo em produção: {metrics['production_model']} ({metrics['production_variant']})")
print(f"Acurácia: {metrics['accuracy']:.2%} | F1 macro: {metrics['f1_macro']:.2%}")
for name, data in metrics['variants'].items():
    print(f"  - {name}: acc {data['accuracy']:.2%} | f1_macro {data['f1_macro']:.2%} | modelo {data['model']}")
